# %%
from os import listdir
import time
import random
import string
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize 
from sklearn.feature_extraction.text import CountVectorizer, HashingVectorizer, TfidfVectorizer
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
import pandas as pd

nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\isacm\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\isacm\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
exclude = set(string.punctuation)
negation = set(["aren't", "isn't", "wasn't", "weren't", "can't", "couldn't", 
    "mustn't", "shouldn't", "won't", "wouldn't", "didn't", "doesn't", "don't", 
    "hasn't", "haven't", "hadn't", "not"])
stop_words = set(stopwords.words('english'))

def remove_punctuation(str_to_alter):
    """
    Takes a string as input and removes punctuation
    """
    global exclude
    new_string = ''.join(ch for ch in str_to_alter if ch not in exclude)

    return new_string

def has_digits(s):
    """
    Returns true if string has digits.
    """
    return any(ch.isdigit() for ch in s)

def is_negation(s):
    """
    Returns True if word will negate coming word 
    """
    global negation

    return s in negation

def is_stopword(s):
    """
    Returns True if the word is in NLTK's list of stop words.
    """
    global stop_words

    return s in stop_words

class Sample:
    """
    Class for holding samples from dataset
    """
    def __init__(self, body, target_class, preprocess=True):
        """
        Inits and preprocesses samples
        """
        self.original = body
        self.body = body
        self.length = len(body)
        self.target_class = int(target_class)
        self.exclamation_point_count = self.body.count('!')
        self.question_mark_count = self.body.count('?')
        self.tokens = list()

        word_tokens = word_tokenize(self.body) 
        
        if preprocess:

            ps =PorterStemmer()
            negation = False
            for w in word_tokens:
                if 'http' in w or '//' in w or '.com' in w:
                    negation = not negation
                    continue
                if '&' in w or '#' in w:
                    negation = not negation
                    continue
                root_word=ps.stem(w)
                if root_word == "n't" or root_word == 'not':
                    negation = not negation
                    continue
                root_word = remove_punctuation(root_word)
                if root_word == 'br':
                    negation = False
                    continue
                elif len(root_word) < 2:
                    negation = False
                    continue
                elif has_digits(root_word):
                    negation = False
                    continue
                elif is_stopword(root_word):
                    negation = False
                    continue
                if negation: 
                    root_word = "".join(('!',root_word))
                    negation = False
                self.tokens.append(root_word)

            self.body = " ".join(self.tokens)


    def __str__(self) -> str:
        """
        Prints first 100 characters of the body if object is printed
        """
        return self.body if len(self.body) < 100 else self.body[:100]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\isacm\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\isacm\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Path to folder with dataset
path = "./data/processed/"

# Lists all files in folder 
files = listdir(path)

df = []

for file in files:
    # Read dataset into dataframe and append to list
    df.append((file, pd.read_csv(f"{path}{file}", sep="\t")))

# For holding dataset with preprocessing
file_content = []
# For holding dataset without preprocessing
file_content_original = []
# For training
ds = []
# For testing
ts = []

random.seed(0)

test_set_probability = .25

for file, dataset in df:
    y_train = []
    y_test = []
    x_train_raw = []
    x_test_raw = []
    for b, s in zip(dataset['review_body'], dataset['star_rating']):
        if random.random() <= test_set_probability:
            # if true add to test set
            train = True
        else:
            train=False
        # Create object with preprocessing from review
        x = Sample(b, 1 if int(s) == 5 else 0)
        if train:
            ds.append(x)
            x_train_raw.append(x.body.strip())
            y_train.append(x.target_class)
        else:
            ts.append(x)
            x_test_raw.append(x.body.strip())
            y_test.append(x.target_class)
    # Append to list
    file_content.append((file, ds, x_train_raw, y_train, ts, x_test_raw, y_test))
    y_train = []
    y_test = []
    x_train_raw = []
    x_test_raw = []
    for b, s in zip(dataset['review_body'], dataset['star_rating']):
        if random.random() <= .25:
            train = True
        else:
            train=False
        # Create object without preprocessing from review
        x = Sample(b, 1 if int(s) == 5 else 0, False)
        if train:
            x_train_raw.append(x.original.strip())
            y_train.append(x.target_class)
        else:
            x_test_raw.append(x.original.strip())
            y_test.append(x.target_class)
    file_content_original.append((file, ds, x_train_raw, y_train, ts, x_test_raw, y_test))
# Out:
# ['dataset_12.9%.csv', 'dataset_20.0%.csv', 'dataset_33.0%.csv', 'dataset_40.0%.csv', 'dataset_50.0%.csv']
# dataset_12.9%.csv
# dataset_20.0%.csv
# dataset_33.0%.csv
# dataset_40.0%.csv
# dataset_50.0%.csv

# %%
# Read tweets into dataframe
df = pd.read_csv(f"./data/tweets.csv")

x_tweets = []
y_tweets = []

random.seed(0)
# Create dataset for testing
for b, s in zip(df['text'], df['sentiment']):
    if not isinstance(b, str):
        break
    if s == 'neutral':
        continue
    x = Sample(b, 1 if s == 'positive' else 0)
    x_tweets.append(x.body.strip())
    y_tweets.append(x.target_class)

# %%
class QuestionMarkExtractor(BaseEstimator, TransformerMixin):
    """Takes in dataframe, extracts number of question marks and outputs a new dataframe"""

    def __init__(self):
        pass

    def transform(self, df, y=None):
        """The workhorse of this feature extractor"""
        return pd.DataFrame([x.count('?') for x in df])

    def fit(self, df, y=None):
        """Returns `self` unless something different happens in train and test"""
        return self

# %%
def eval_result(predicted, y):
    """
    Takes predicted class and target class and returns a dict containing 
    evaluation statistics"""
    
    tp, tn, fp, fn = 0,0,0,0
    stat = dict()

    for y_hat, y_ in zip(predicted, y):
        if y_hat == 1:
            if y_ == 1:
                tp +=1
            else:
                fp += 1
        else:
            if y_ == 1:
                fn += 1
            else:
                tn +=1
    # (TP+TN)/(TP+TN+FP+FN)
    accuracy = (tp+tn)/(tp+fp+fn+tn)
    # TP/(TN+FN)
    precision = tp/(tp+fp)
    # TP/(TP+FN)
    recall = tp/(tp+fn)
    # 2*recall*precision/(recall+precision)
    f1 = 2*(recall * precision) / (recall + precision)

    stat["Accuracy"] = accuracy
    stat["Precision"] = precision
    stat["Recall"] = recall
    stat["F1-Score"] = f1
    stat["TP"] = tp
    stat["TN"] = tn
    stat["FP"] = fp
    stat["FN"] = fn

    return stat

# %%
def get_model(model, vectorizer, qm, binary, stop_words, additional_settings, ngrams):
    """
    Takes arguments on what model, vectorizer and settings should be used. 
    Outputs a pipeline with feature extractors and ml algorithm 
    """

    # ML model to use
    if model == 'Naïve Bayes':
        m = MultinomialNB()
    elif model == "Support Vector Machine":
        if additional_settings:
            m = svm.SVC(kernel='linear', verbose=False, C=0.67)
        else:
            m = svm.SVC()
    elif model == 'Random Forest':
        if additional_settings:
            m = RandomForestClassifier(n_estimators=500 ,criterion='entropy', random_state=0, verbose=0, n_jobs=8)
        else:
            m = RandomForestClassifier(random_state=0, verbose=0, n_jobs=8)
    
    # Feature Extractor
    if vectorizer == 'CountVectorizer':
        vec = CountVectorizer(stop_words=stop_words, binary=binary, ngram_range=ngrams)
    elif vectorizer == "HashingVectorizer":
        vec = HashingVectorizer(stop_words=stop_words, binary=binary, ngram_range=ngrams)
    elif vectorizer == "TfidfVectorizer":
        if additional_settings:
            vec = TfidfVectorizer(stop_words=stop_words, binary=binary, smooth_idf=False, ngram_range=ngrams)
        else:
            vec = TfidfVectorizer(stop_words=stop_words, binary=binary, ngram_range=ngrams)

    feature_union = [('vec', vec)]
    # If question mark count should be considered as a feature.
    if qm:
        feature_union.append(('qm', QuestionMarkExtractor()))

    ppl = Pipeline([
        ('feats', FeatureUnion(feature_union)),
        ('model', m)
    ]) 

    return ppl

models = ['Support Vector Machine' , 'Naïve Bayes' , 'Random Forest']
vectorizers = ["TfidfVectorizer", 'CountVectorizer', "HashingVectorizer"]

result_df = pd.DataFrame()
best_accuracy = 0

for preprocessed, data_list in zip([True, False], [file_content, file_content_original]):
    for file in data_list:
        print('\n' + '-'*100 + '\n' + file[0] + '\n' + '-'*100)
        for vec in vectorizers:
            for ml_model in models:
                for ngrams in ([1, 1], [1, 2]):
                    for qm in [True, False]:
                        for binary in [True, False]:
                            for stop_words in ['english', None]:
                                for additional_settings in [True, False]:
                                    print(f"{'-'*100}\nPreprocessed data: {preprocessed}")
                                    print(f"Dataset: {file[0][:-4]}")
                                    print(f"Feature extraction: {vec}")
                                    print(f"Algorithm: {ml_model}")
                                    print(f"Ngrams: {ngrams}")
                                    print(f"Question mark count as feature: {qm}")
                                    print(f"Binary representation: {binary}")
                                    print(f"Stop words: {stop_words}")
                                    print(f"Additional settings: {additional_settings}")
                                    try:
                                        # Getting the pipeline
                                        model = get_model(ml_model, vec, qm, binary, stop_words, additional_settings, ngrams)
                                        t0 = time.time()
                                        # Fitting
                                        model.fit(file[2], file[3])
                                        t1 = time.time()
                                        # Predictions on testset with standard distribution (12.9% negative)
                                        y_hat = model.predict(file_content[0][5])
                                        t2 = time.time()
                                        fitting_time = t1-t0
                                        result = eval_result(y_hat, file_content[0][6])
                                        if best_accuracy < result['Accuracy']:
                                            best_accuracy = result['Accuracy']
                                            print(best_accuracy)
                                        result['Algorithm'] = ml_model
                                        result['Ngrams'] = ngrams
                                        result['Feature Extraction'] = vec
                                        result['Training Dataset'] = file[0][:-4]
                                        result['Test Dataset'] = file_content[0][0][:-4]
                                        result['Test Distribution'] =  f'{round(100*(file_content[0][6].count(1)/len(file_content[0][6])), 2)}/{round(100*(file_content[0][6].count(0)/len(file_content[0][6])),2)}'
                                        result['F_Question_mark'] = qm
                                        result['Binary Representation'] = binary
                                        result['Stop words'] = stop_words
                                        result['Additional Settings'] = additional_settings
                                        result['Fitting Time'] = fitting_time
                                        result['Prediction Time'] = t2-t1
                                        result_df = result_df.append(result, ignore_index=True)
                                        # Predictions on testset with same distribution like it has been fitted with.
                                        t1 = time.time()
                                        y_hat = model.predict(file[5])
                                        t2 = time.time()
                                        result = eval_result(y_hat, file[6])
                                        if best_accuracy < result['Accuracy']:
                                            best_accuracy = result['Accuracy']
                                            print(best_accuracy)
                                        result['Algorithm'] = ml_model
                                        result['Ngrams'] = ngrams
                                        result['Feature Extraction'] = vec
                                        result['Training Dataset'] = file[0][:-4]
                                        result['Test Dataset'] = file[0][:-4]
                                        result['Test Distribution'] = f'{round(100*(file[6].count(1)/len(file[6])), 2)}/{round(100*(file[6].count(0)/len(file[6])),2)}'
                                        result['F_Question_mark'] = qm
                                        result['Binary Representation'] = binary
                                        result['Stop words'] = stop_words
                                        result['Additional Settings'] = additional_settings
                                        result['Fitting Time'] = fitting_time
                                        result['Prediction Time'] = t2-t1
                                        result_df = result_df.append(result, ignore_index=True)
                                        # Predictions on Twitter dataset
                                        t1 = time.time()
                                        y_hat = model.predict(x_tweets)
                                        t2 = time.time()
                                        result = eval_result(y_hat, y_tweets)
                                        if best_accuracy < result['Accuracy']:
                                            best_accuracy = result['Accuracy']
                                            print(best_accuracy)
                                        result['Algorithm'] = ml_model
                                        result['Ngrams'] = ngrams
                                        result['Feature Extraction'] = vec
                                        result['Training Dataset'] = file[0][:-4]
                                        result['Test Dataset'] = "tweets"
                                        result['Test Distribution'] = f'{round(100*(y_tweets.count(1)/len(y_tweets)), 2)}/{round(100*(y_tweets.count(0)/len(y_tweets)), 2)}'
                                        result['F_Question_mark'] = qm
                                        result['Binary Representation'] = binary
                                        result['Stop words'] = stop_words
                                        result['Additional Settings'] = additional_settings
                                        result['Fitting Time'] = fitting_time
                                        result['Prediction Time'] = t2-t1
                                        result_df = result_df.append(result, ignore_index=True)
                                    except Exception as e:
                                        print(e)
# Out:
# ----------------------------------------------------------------------------------------------------
# dataset_12.9%.csv
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: True
# Stop words: english
# Additional settings: True
# 0.916538426722187
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: True
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: True
# Stop words: None
# Additional settings: True
# 0.917081560604689
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: True
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: False
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: False
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: False
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: False
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: True
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: True
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: True
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: True
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: False
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: False
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: False
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: False
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: True
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: True
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: True
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: True
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: False
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: False
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: False
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: False
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: True
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: True
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: True
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: True
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: False
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: False
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: False
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: False
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: True
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: True
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: True
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: True
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: False
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: False
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: False
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: False
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: True
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: True
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: True
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: True
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: False
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: False
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: False
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: False
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: True
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: True
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: True
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: True
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: False
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: False
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: False
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: False
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: True
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: True
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: True
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: True
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: False
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: False
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: False
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: False
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: True
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: True
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: True
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: True
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: False
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: False
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: False
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: False
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: True
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: True
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: True
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: True
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: False
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: False
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: False
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: False
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: True
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: True
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: True
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: True
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: False
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: False
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: False
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: False
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: True
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: True
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: True
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: True
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: False
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: False
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: False
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: TfidfVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: False
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: True
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: True
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: True
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: True
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: False
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: False
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: False
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: False
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: True
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: True
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: True
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: True
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: False
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: False
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: False
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: False
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: True
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: True
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: True
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: True
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: False
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: False
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: False
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: False
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: True
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: True
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: True
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: True
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: False
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: False
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: False
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Support Vector Machine
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: False
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: True
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: True
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: True
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: True
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: False
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: False
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: False
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: False
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: True
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: True
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: True
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: True
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: True
# Dataset: dataset_12.9%
# Feature extraction: CountVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: False
# Stop words: english
# Additional settings: True
# ...
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: True
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: True
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: False
# Stop words: english
# Additional settings: True
# Negative values in data passed to MultinomialNB (input X)
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: False
# Stop words: english
# Additional settings: False
# Negative values in data passed to MultinomialNB (input X)
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: False
# Stop words: None
# Additional settings: True
# Negative values in data passed to MultinomialNB (input X)
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: False
# Stop words: None
# Additional settings: False
# Negative values in data passed to MultinomialNB (input X)
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: True
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: True
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: True
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: True
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: False
# Stop words: english
# Additional settings: True
# Negative values in data passed to MultinomialNB (input X)
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: False
# Stop words: english
# Additional settings: False
# Negative values in data passed to MultinomialNB (input X)
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: False
# Stop words: None
# Additional settings: True
# Negative values in data passed to MultinomialNB (input X)
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Naïve Bayes
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: False
# Stop words: None
# Additional settings: False
# Negative values in data passed to MultinomialNB (input X)
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: True
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: True
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: True
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: True
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: False
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: False
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: False
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 1]
# Question mark count as feature: True
# Binary representation: False
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: True
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: True
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: True
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: True
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: False
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: False
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: False
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 1]
# Question mark count as feature: False
# Binary representation: False
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: True
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: True
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: True
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: True
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: False
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: False
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: False
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 2]
# Question mark count as feature: True
# Binary representation: False
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: True
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: True
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: True
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: True
# Stop words: None
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: False
# Stop words: english
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: False
# Stop words: english
# Additional settings: False
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: False
# Stop words: None
# Additional settings: True
# ----------------------------------------------------------------------------------------------------
# Preprocessed data: False
# Dataset: dataset_50.0%
# Feature extraction: HashingVectorizer
# Algorithm: Random Forest
# Ngrams: [1, 2]
# Question mark count as feature: False
# Binary representation: False
# Stop words: None
# Additional settings: False

# %%
result_df.to_csv('Results.csv', index=False)

# %%
result_df.sort_values(by=['Accuracy'], ascending=False)
# Out:
#       Accuracy  Precision    Recall  F1-Score      TP      TN      FP     FN  \
# 1710  0.940346   0.962528  0.969414  0.965959  9350.0  1038.0   364.0  295.0
# 1686  0.940346   0.962528  0.969414  0.965959  9350.0  1038.0   364.0  295.0
# 1713  0.939893   0.949275  0.983722  0.966191  9488.0   895.0   507.0  157.0
# 1689  0.939893   0.949275  0.983722  0.966191  9488.0   895.0   507.0  157.0
# 1680  0.939260   0.961341  0.969414  0.965361  9350.0  1026.0   376.0  295.0
# ...        ...        ...       ...       ...     ...     ...     ...    ...
# 5627  0.523764   0.524013  0.999093  0.687461  1102.0     0.0  1001.0    1.0
# 6911  0.523764   0.524013  0.999093  0.687461  1102.0     0.0  1001.0    1.0
# 6887  0.523764   0.524013  0.999093  0.687461  1102.0     0.0  1001.0    1.0
# 6059  0.523764   0.524013  0.999093  0.687461  1102.0     0.0  1001.0    1.0
# 5663  0.523764   0.524013  0.999093  0.687461  1102.0     0.0  1001.0    1.0
#
#                    Algorithm  Ngrams Feature Extraction Training Dataset  \
# 1710  Support Vector Machine  [1, 2]    TfidfVectorizer    dataset_33.0%
# 1686  Support Vector Machine  [1, 2]    TfidfVectorizer    dataset_33.0%
# 1713  Support Vector Machine  [1, 2]    TfidfVectorizer    dataset_33.0%
# 1689  Support Vector Machine  [1, 2]    TfidfVectorizer    dataset_33.0%
# 1680  Support Vector Machine  [1, 2]    TfidfVectorizer    dataset_33.0%
# ...                      ...     ...                ...              ...
# 5627           Random Forest  [1, 1]  HashingVectorizer    dataset_20.0%
# 6911  Support Vector Machine  [1, 2]    CountVectorizer    dataset_40.0%
# 6887  Support Vector Machine  [1, 2]    CountVectorizer    dataset_40.0%
# 6059  Support Vector Machine  [1, 2]    CountVectorizer    dataset_33.0%
# 5663           Random Forest  [1, 1]  HashingVectorizer    dataset_20.0%
#
#        Test Dataset Test Distribution F_Question_mark Binary Representation  \
# 1710  dataset_12.9%       87.31/12.69           False                  True
# 1686  dataset_12.9%       87.31/12.69            True                  True
# 1713  dataset_12.9%       87.31/12.69           False                  True
# 1689  dataset_12.9%       87.31/12.69            True                  True
# 1680  dataset_12.9%       87.31/12.69            True                  True
# ...             ...               ...             ...                   ...
# 5627         tweets       52.42/47.58            True                  True
# 6911         tweets       52.42/47.58           False                 False
# 6887         tweets       52.42/47.58            True                 False
# 6059         tweets       52.42/47.58            True                  True
# 5663         tweets       52.42/47.58           False                 False
#
#      Stop words Additional Settings  Fitting Time  Prediction Time
# 1710       None                True      3.170261         7.629600
# 1686       None                True      3.168179         7.658349
# 1713       None               False      3.818651         8.734709
# 1689       None               False      3.742381         8.693122
# 1680    english                True      2.828577         6.769842
# ...         ...                 ...           ...              ...
# 5627       None               False     37.511606         0.251387
# 6911       None               False      5.496673         0.988782
# 6887       None               False      5.513392         0.997308
# 6059       None               False      5.440236         1.007892
# 5663       None               False     37.167161         0.256030
#
# [8160 rows x 20 columns]
